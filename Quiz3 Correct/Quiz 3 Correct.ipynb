# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 3 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here

print ('Leonard Henshaw')
# Out:
# Leonard Henshaw

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print ("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy" and "pandas"

# %%
# Write your answer here

import numpy as np
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# (a) Replace the values of a column
#
# <font size = "3">
#
# - Import the "data_raw/constructors.csv" file
# - Replace the values "British", "American", and "Dutch" with <br>
# "UK", "USA", "Netherlands" in the column "nationality"
#
#
# HINT: See the example in Lecture 12

# %%
# Write your own code

constructors = pd.read_csv('data_raw/constructors.csv')
constructors['nationality'] = constructors['nationality'].replace({'British': 'UK', 'American': 'USA', 'Dutch': 'Netherlands'})

# %% [markdown]
# <font size = "5">
#
#
# <span style="color:red"> For QUESTIONS (b)-(e): </span>
#
# <span style="color:red"> Import the "data_raw/sprint_results.csv" file </span>
#
#
# (b) Recode a numeric colum
#
# <font size = "3">
#
# - Recode the "points" column into a new column "points_brackets" <br>
# with the following categories
#
# $\qquad$ ``` ["0-20","21-30","31-100"] ```
#
# $\qquad$ HINT: Use the "pd.cut()" command. See Lecture 12 <br>
# $\qquad$ HINT: Be careful about the left and right points of <br>
# $\qquad$ interval to make sure that you classify the points correctly

# %%
# Write your own code:

bins = [-np.inf, 20, 30, np.inf]
labels = ["0-20","21-30","31-100"]

sprint_results = pd.read_csv('data_raw/sprint_results.csv')
sprint_results['points_brackets'] = pd.cut(sprint_results['points'],
                                            bins = bins, 
                                            labels = labels)

# %% [markdown]
# <font size = "5">
#
# (c) Aggregate and query
#
# <font size = "3">
#
# - Subset the observations for 'raceId <= 1070' using ```.query()```
# - Obtain the maximum of "points" by "driverId" <br>  using ``` .groupby().agg() ``` and save this to <br>
# a new dataset called "aggregate_data"
# - From "aggregate_data" subset the drivers with a maximum number of points $>= 1$
# - Display the resulting dataset
#
#
# Hint: See Lecture 15

# %%
# Write your own code

filtered_sprint_results = sprint_results.query('raceId <= 1070')
aggregate_data = filtered_sprint_results.groupby('driverId').agg({'points': 'max'})
aggregate_data = aggregate_data[aggregate_data['points'] >= 1]

filtered_sprint_results
# Out:
#     resultId  raceId  driverId  constructorId  number  grid position  \
# 0          1    1061       830              9      33     2        1
# 1          2    1061         1            131      44     1        2
# 2          3    1061       822            131      77     3        3
# 3          4    1061       844              6      16     4        4
# 4          5    1061       846              1       4     6        5
# 5          6    1061       817              1       3     7        6
# 6          7    1061         4            214      14    11        7
# 7          8    1061        20            117       5    10        8
# 8          9    1061       847              3      63     8        9
# 9         10    1061       839            214      31    13       10
# 10        11    1061       832              6      55     9       11
# 11        12    1061       842            213      10    12       12
# 12        13    1061         8             51       7    17       13
# 13        14    1061       840            117      18    15       14
# 14        15    1061       841             51      99    14       15
# 15        16    1061       852            213      22    16       16
# 16        17    1061       849              3       6    18       17
# 17        18    1061       854            210      47    19       18
# 18        19    1061       853            210       9    20       19
# 19        20    1061       815              9      11     5       \N
# 20        21    1065       822            131      77     1        1
# 21        22    1065       830              9      33     3        2
# 22        23    1065       817              1       3     5        3
# 23        24    1065       846              1       4     4        4
# 24        25    1065         1            131      44     2        5
# 25        26    1065       844              6      16     8        6
# 26        27    1065       832              6      55     7        7
# 27        28    1065       841             51      99    10        8
# 28        29    1065       815              9      11     9        9
# 29        30    1065       840            117      18    12       10
# 30        31    1065         4            214      14    13       11
# 31        32    1065        20            117       5    11       12
# 32        33    1065       839            214      31    14       13
# 33        34    1065       849              3       6    16       14
# 34        35    1065       847              3      63    15       15
# 35        36    1065       852            213      22    17       16
# 36        37    1065       853            210       9    20       17
# 37        38    1065         9             51      88    19       18
# 38        39    1065       854            210      47    18       19
# 39        40    1065       842            213      10     6       \N
#
#    positionText  positionOrder  points  laps       time milliseconds  \
# 0             1              1       3    17  25:38.426      1538426
# 1             2              2       2    17     +1.430      1539856
# 2             3              3       1    17     +7.502      1545928
# 3             4              4       0    17    +11.278      1549704
# 4             5              5       0    17    +24.111      1562537
# 5             6              6       0    17    +30.959      1569385
# 6             7              7       0    17    +43.527      1581953
# 7             8              8       0    17    +44.439      1582865
# 8             9              9       0    17    +46.652      1585078
# 9            10             10       0    17    +47.395      1585821
# 10           11             11       0    17    +47.798      1586224
# 11           12             12       0    17    +48.763      1587189
# 12           13             13       0    17    +50.677      1589103
# 13           14             14       0    17    +52.179      1590605
# 14           15             15       0    17    +53.225      1591651
# 15           16             16       0    17    +53.567      1591993
# 16           17             17       0    17    +55.162      1593588
# 17           18             18       0    17  +1:08.213      1606639
# 18           19             19       0    17  +1:17.648      1616074
# 19            R             20       0    16         \N           \N
# 20            1              1       3    18  27:54.078      1674078
# 21            2              2       2    18     +2.325      1676403
# 22            3              3       1    18    +14.534      1688612
# 23            4              4       0    18    +18.835      1692913
# 24            5              5       0    18    +20.011      1694089
# 25            6              6       0    18    +23.442      1697520
# 26            7              7       0    18    +27.952      1702030
# 27            8              8       0    18    +31.089      1705167
# 28            9              9       0    18    +31.680      1705758
# 29           10             10       0    18    +38.671      1712749
# 30           11             11       0    18    +39.795      1713873
# 31           12             12       0    18    +41.177      1715255
# 32           13             13       0    18    +43.373      1717451
# 33           14             14       0    18    +45.977      1720055
# 34           15             15       0    18    +46.821      1720899
# 35           16             16       0    18    +49.977      1724055
# 36           17             17       0    18  +1:02.599      1736677
# 37           18             18       0    18  +1:05.096      1739174
# 38           19             19       0    18  +1:06.154      1740232
# 39            R             20       0     0         \N           \N
#
#    fastestLap fastestLapTime  statusId points_brackets
# 0          14       1:30.013         1            0-20
# 1          17       1:29.937         1            0-20
# 2          17       1:29.958         1            0-20
# 3          16       1:30.163         1            0-20
# 4          16       1:30.566         1            0-20
# 5          17       1:30.640         1            0-20
# 6          17       1:31.773         1            0-20
# 7          17       1:31.687         1            0-20
# 8          17       1:32.208         1            0-20
# 9          16       1:32.183         1            0-20
# 10         10       1:31.991         1            0-20
# 11         17       1:32.072         1            0-20
# 12         12       1:32.139         1            0-20
# 13         12       1:32.210         1            0-20
# 14         14       1:32.457         1            0-20
# 15         14       1:32.270         1            0-20
# 16         17       1:32.143         1            0-20
# 17         15       1:32.567         1            0-20
# 18          3       1:33.462         1            0-20
# 19          6       1:31.465        76            0-20
# 20          9       1:23.540         1            0-20
# 21          9       1:23.502         1            0-20
# 22         17       1:24.291         1            0-20
# 23          9       1:24.554         1            0-20
# 24          9       1:24.253         1            0-20
# 25         18       1:24.677         1            0-20
# 26          8       1:24.918         1            0-20
# 27         10       1:25.126         1            0-20
# 28         12       1:24.211         1            0-20
# 29          8       1:25.349         1            0-20
# 30          8       1:25.225         1            0-20
# 31          8       1:25.493         1            0-20
# 32          8       1:25.613         1            0-20
# 33          9       1:25.711         1            0-20
# 34         15       1:25.835         1            0-20
# 35         18       1:25.847         1            0-20
# 36          7       1:26.613         1            0-20
# 37         12       1:26.772         1            0-20
# 38          7       1:26.819         1            0-20
# 39         \N             \N         3            0-20

# %% [markdown]
# <font size = "5">
#
# (d) Aggregate and sort
#
# <font size = "3">
#
# - Obtain the mean of "points" by "driverId" <br>  using ``` .groupby().agg() ```
# - Sort the drivers in descending order using of <br>
# the mean of points using ``` .sort_values() ```
#
#
# Hint: See Lecture 15

# %%
# Write your own code

mean_points = sprint_results.groupby('driverId').agg({'points': 'mean'}).sort_values(by='points', ascending=False)

# %% [markdown]
# <font size = "5">
#
# (e) Rename column
#
# <font size = "3">
#
# - Rename the column "grid" to "grid_placement"
#
# HINT: Create a dictionary and use ```.rename(columns = ...)``` <br>
# See Lecture 15

# %%
# Write your own code

sprint_results = sprint_results.rename(columns={'grid': 'grid_placement'})

# %% [markdown]
# <font size = "5">
#
# (f) Merge dataset
#
# <font size = "3">
#
# - Create a new dataset with  ```pd.merge()``` using <br>
# "sprint_results" as the primary dataset, and <br>
# "constructors" as the secondary dataset, merging on <br>
# the column "constructorId"
# - To get full points **ONLY** merge the "nationality" column <br>
# from the secondary dataset (not all the columns)
#
# HINT: Use ```[[...]]``` to extract a subset of columns <br>
# from the secondary dataset before merging, including the <br>
# "constructorId" column. <br>
# Be careful to notice that "constructorId" has an uppercase "I".
#
# See Lecture 15

# %%
# Write your own code

merged_data = pd.merge(sprint_results, constructors[['constructorId', 'nationality']], on='constructorId')
